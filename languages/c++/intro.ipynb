# %%
#include <iostream>
using namespace std;

int main() {
  cout << "Hello World!";
  return 0;
}
# Out:
#   Cell In[1], line 2
#     using namespace std;
#           ^
# SyntaxError: invalid syntax
